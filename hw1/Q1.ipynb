# %%
#STUDENT NAME: SHRUTHI
#STUDENT ID: 801218392
#HOMEWORK 1 QUESTION 1

# %%
from PIL import Image

# %%
#red images
imager1=Image.open('C:/Users/Shruthi/Documents/HWs/RTML/hw1/images/apple.jpg')
imager2=Image.open('C:/Users/Shruthi/Documents/HWs/RTML/hw1/images/capsicum.jfif')
imager3=Image.open('C:/Users/Shruthi/Documents/HWs/RTML/hw1/images/raspberry.jfif')
imager4=Image.open('C:/Users/Shruthi/Documents/HWs/RTML/hw1/images/strawberry.jpg')
imager5=Image.open('C:/Users/Shruthi/Documents/HWs/RTML/hw1/images/tomato.jpg')

# %%
#blue images
imageb1=Image.open('C:/Users/Shruthi/Documents/HWs/RTML/hw1/images/bluebells.jpg')
imageb2=Image.open('C:/Users/Shruthi/Documents/HWs/RTML/hw1/images/forget-me-not.jfif')
imageb3=Image.open('C:/Users/Shruthi/Documents/HWs/RTML/hw1/images/orchids.jpg')
imageb4=Image.open('C:/Users/Shruthi/Documents/HWs/RTML/hw1/images/rose.jfif')
imageb5=Image.open('C:/Users/Shruthi/Documents/HWs/RTML/hw1/images/tulip.jpg')

# %%
#green images
imageg1=Image.open('C:/Users/Shruthi/Documents/HWs/RTML/hw1/images/emeralds.jpg')
imageg2=Image.open('C:/Users/Shruthi/Documents/HWs/RTML/hw1/images/garnet.jpg')
imageg3=Image.open('C:/Users/Shruthi/Documents/HWs/RTML/hw1/images/jade.jpg')
imageg4=Image.open('C:/Users/Shruthi/Documents/HWs/RTML/hw1/images/quartz.jpg')
imageg5=Image.open('C:/Users/Shruthi/Documents/HWs/RTML/hw1/images/tourmaline.jpg')

# %%
import torchvision.transforms as transforms
transform=transforms.ToTensor()

# %%
#Taking the mean of the entire 3channel tensor and individual channels for each tensor for each red image
import torch
tensorr1=transform(imager1)
print("Mean of apples-", torch.mean(tensorr1).numpy())
meanr11=torch.mean(tensorr1[0,:,:])
print("The mean across the first channel is ",  meanr11.numpy())
meanr12=torch.mean(tensorr1[1,:,:])
print("The mean across the second channel is ",  meanr12.numpy())
meanr13=torch.mean(tensorr1[2,:,:])
print("The mean across the third channel is ",  meanr13.numpy())
print("\n")

tensorr2=transform(imager2)
print("Mean of capsicum-", torch.mean(tensorr2).numpy())
meanr21=torch.mean(tensorr2[0,:,:])
print("The mean across the first channel is ",  meanr21.numpy())
meanr22=torch.mean(tensorr2[1,:,:])
print("The mean across the second channel is ",  meanr22.numpy())
meanr23=torch.mean(tensorr2[2,:,:])
print("The mean across the third channel is ",  meanr23.numpy())
print("\n")

tensorr3=transform(imager3)
print("Mean of raspberry-", torch.mean(tensorr3).numpy())
meanr31=torch.mean(tensorr3[0,:,:])
print("The mean across the first channel is ",  meanr31.numpy())
meanr32=torch.mean(tensorr3[1,:,:])
print("The mean across the second channel is ",  meanr32.numpy())
meanr33=torch.mean(tensorr3[2,:,:])
print("The mean across the third channel is ",  meanr33.numpy())
print("\n")

tensorr4=transform(imager4)
print("Mean of strawberry-", torch.mean(tensorr4).numpy())
meanr41=torch.mean(tensorr4[0,:,:])
print("The mean across the first channel is ",  meanr41.numpy())
meanr42=torch.mean(tensorr4[1,:,:])
print("The mean across the second channel is ",  meanr42.numpy())
meanr43=torch.mean(tensorr4[2,:,:])
print("The mean across the third channel is ",  meanr43.numpy())
print("\n")

tensorr5=transform(imager5)
print("Mean of tomatoes-", torch.mean(tensorr5).numpy())
meanr51=torch.mean(tensorr5[0,:,:])
print("The mean across the first channel is ",  meanr51.numpy())
meanr52=torch.mean(tensorr5[1,:,:])
print("The mean across the second channel is ",  meanr52.numpy())
meanr53=torch.mean(tensorr5[2,:,:])
print("The mean across the third channel is ",  meanr53.numpy())
print("\n")
# Out:
# Mean of apples- 0.3904894
# The mean across the first channel is  0.7405986
# The mean across the second channel is  0.24033882
# The mean across the third channel is  0.19053078
#
#
# Mean of capsicum- 0.35839817
# The mean across the first channel is  0.66021776
# The mean across the second channel is  0.22623532
# The mean across the third channel is  0.18874136
#
#
# Mean of raspberry- 0.34074217
# The mean across the first channel is  0.6790574
# The mean across the second channel is  0.13913733
# The mean across the third channel is  0.20403177
#
#
# Mean of strawberry- 0.3056839
# The mean across the first channel is  0.63399756
# The mean across the second channel is  0.15700546
# The mean across the third channel is  0.12604858
#
#
# Mean of tomatoes- 0.37028563
# The mean across the first channel is  0.7643162
# The mean across the second channel is  0.2184474
# The mean across the third channel is  0.12809323

# %%
#Taking the mean of the entire 3channel tensor and individual channels for each tensor for each blue image
tensorb1=transform(imageb1)
print("Mean of bluebells-", torch.mean(tensorb1).numpy())
meanb11=torch.mean(tensorb1[0,:,:])
print("The mean across the first channel is ",  meanb11.numpy())
meanb12=torch.mean(tensorb1[1,:,:])
print("The mean across the second channel is ",  meanb12.numpy())
meanb13=torch.mean(tensorb1[2,:,:])
print("The mean across the third channel is ",  meanb13.numpy())
print("\n")

tensorb2=transform(imageb2)
print("Mean of forget-me-nots-", torch.mean(tensorb2).numpy())
meanb21=torch.mean(tensorb2[0,:,:])
print("The mean across the first channel is ",  meanb21.numpy())
meanb22=torch.mean(tensorb2[1,:,:])
print("The mean across the second channel is ",  meanb22.numpy())
meanb23=torch.mean(tensorb2[2,:,:])
print("The mean across the third channel is ",  meanb23.numpy())
print("\n")

tensorb3=transform(imageb3)
print("Mean of orchids-", torch.mean(tensorb3).numpy())
meanb31=torch.mean(tensorb3[0,:,:])
print("The mean across the first channel is ",  meanb31.numpy())
meanb32=torch.mean(tensorb3[1,:,:])
print("The mean across the second channel is ",  meanb32.numpy())
meanb33=torch.mean(tensorb3[2,:,:])
print("The mean across the third channel is ",  meanb33.numpy())
print("\n")

tensorb4=transform(imageb4)
print("Mean of rose-", torch.mean(tensorb4).numpy())
meanb41=torch.mean(tensorb4[0,:,:])
print("The mean across the first channel is ",  meanb41.numpy())
meanb42=torch.mean(tensorb4[1,:,:])
print("The mean across the second channel is ",  meanb42.numpy())
meanb43=torch.mean(tensorb4[2,:,:])
print("The mean across the third channel is ",  meanb43.numpy())
print("\n")

tensorb5=transform(imageb5)
print("Mean of tulips-", torch.mean(tensorb5).numpy())
meanb51=torch.mean(tensorb5[0,:,:])
print("The mean across the first channel is ",  meanb51.numpy())
meanb52=torch.mean(tensorb5[1,:,:])
print("The mean across the second channel is ",  meanb52.numpy())
meanb53=torch.mean(tensorb5[2,:,:])
print("The mean across the third channel is ",  meanb53.numpy())
print("\n")
# Out:
# Mean of bluebells- 0.4857608
# The mean across the first channel is  0.3158588
# The mean across the second channel is  0.43228102
# The mean across the third channel is  0.7091427
#
#
# Mean of forget-me-nots- 0.6184666
# The mean across the first channel is  0.4567839
# The mean across the second channel is  0.6062225
# The mean across the third channel is  0.79239374
#
#
# Mean of orchids- 0.64063185
# The mean across the first channel is  0.39772862
# The mean across the second channel is  0.6978783
# The mean across the third channel is  0.82628834
#
#
# Mean of rose- 0.33265445
# The mean across the first channel is  0.050233863
# The mean across the second channel is  0.3209345
# The mean across the third channel is  0.62679505
#
#
# Mean of tulips- 0.4830518
# The mean across the first channel is  0.043863516
# The mean across the second channel is  0.57908237
# The mean across the third channel is  0.8262094

# %%
#Taking the mean of the entire 3channel tensor and individual channels for each tensor for each green image
tensorg1=transform(imageg1)
print("Mean of emerald-", torch.mean(tensorg1).numpy())
meang11=torch.mean(tensorg1[0,:,:])
print("The mean across the first channel is ",  meang11.numpy())
meang12=torch.mean(tensorg1[1,:,:])
print("The mean across the second channel is ",  meang12.numpy())
meang13=torch.mean(tensorg1[2,:,:])
print("The mean across the third channel is ",  meang13.numpy())
print("\n")

tensorg2=transform(imageg2)
print("Mean of garnet-", torch.mean(tensorg2).numpy())
meang21=torch.mean(tensorg2[0,:,:])
print("The mean across the first channel is ",  meang21.numpy())
meang22=torch.mean(tensorg2[1,:,:])
print("The mean across the second channel is ",  meang22.numpy())
meang23=torch.mean(tensorg2[2,:,:])
print("The mean across the third channel is ",  meang23.numpy())
print("\n")

tensorg3=transform(imageg3)
print("Mean of jade-", torch.mean(tensorg3).numpy())
meang31=torch.mean(tensorg3[0,:,:])
print("The mean across the first channel is ",  meang31.numpy())
meang32=torch.mean(tensorg3[1,:,:])
print("The mean across the second channel is ",  meang32.numpy())
meang33=torch.mean(tensorg3[2,:,:])
print("The mean across the third channel is ",  meang33.numpy())
print("\n")

tensorg4=transform(imageg4)
print("Mean of quartz-", torch.mean(tensorg4).numpy())
meang41=torch.mean(tensorg4[0,:,:])
print("The mean across the first channel is ",  meang41.numpy())
meang42=torch.mean(tensorg4[1,:,:])
print("The mean across the second channel is ",  meang42.numpy())
meang43=torch.mean(tensorg4[2,:,:])
print("The mean across the third channel is ",  meang43.numpy())
print("\n")

tensorg5=transform(imageg5)
print("Mean of tourmaline-", torch.mean(tensorg5).numpy())
meang51=torch.mean(tensorg5[0,:,:])
print("The mean across the first channel is ",  meang51.numpy())
meang52=torch.mean(tensorg5[1,:,:])
print("The mean across the second channel is ",  meang52.numpy())
meang53=torch.mean(tensorg5[2,:,:])
print("The mean across the third channel is ",  meang53.numpy())
print("\n")
# Out:
# Mean of emerald- 0.19996658
# The mean across the first channel is  0.08565943
# The mean across the second channel is  0.314898
# The mean across the third channel is  0.19934225
#
#
# Mean of garnet- 0.71798784
# The mean across the first channel is  0.67785436
# The mean across the second channel is  0.7779361
# The mean across the third channel is  0.6981729
#
#
# Mean of jade- 0.6650606
# The mean across the first channel is  0.6514821
# The mean across the second channel is  0.72063285
# The mean across the third channel is  0.6230667
#
#
# Mean of quartz- 0.7224294
# The mean across the first channel is  0.6865044
# The mean across the second channel is  0.7727187
# The mean across the third channel is  0.708065
#
#
# Mean of tourmaline- 0.56719047
# The mean across the first channel is  0.54127234
# The mean across the second channel is  0.6602939
# The mean across the third channel is  0.50000507
